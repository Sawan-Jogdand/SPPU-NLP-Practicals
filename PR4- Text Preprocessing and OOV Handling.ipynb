# %%
pip install nltk pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Sentence Segmentation
import nltk
from nltk.tokenize import sent_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

text = "I love this movie. The acting is excellent! I will watch it again."

sentences = sent_tokenize(text)

print("Sentences:")

for sentence in sentences:
    print(sentence)
# Out:
# Sentences:
# I love this movie.
# The acting is excellent!
# I will watch it again.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#Tokenization

import nltk
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

text = "I love Natural Language Processing."

tokens = word_tokenize(text)

print("Tokens:")
print(tokens)
# Out:
# Tokens:
# ['I', 'love', 'Natural', 'Language', 'Processing', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#Stopword Removal

import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')

text = "I love this movie because it is very good."

tokens = word_tokenize(text.lower())

stop_words = set(stopwords.words("english"))

result = []

for word in tokens:
    if word not in stop_words:
        result.append(word)

print("Before:")
print(tokens)

print("After Stopword Removal:")
print(result)
# Out:
# Before:
# ['i', 'love', 'this', 'movie', 'because', 'it', 'is', 'very', 'good', '.']
# After Stopword Removal:
# ['love', 'movie', 'good', '.']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Stemming

from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["playing", "played", "plays", "studies", "connected", "running"]

print("Original Words:")
print(words)

print("Stemmed Words:")

for word in words:
    print(word, "->", stemmer.stem(word))
# Out:
# Original Words:
# ['playing', 'played', 'plays', 'studies', 'connected', 'running']
# Stemmed Words:
# playing -> play
# played -> play
# plays -> play
# studies -> studi
# connected -> connect
# running -> run

# %%
#Lemmatization

import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

words = ["playing", "played", "studies", "cars", "running"]

print("Original Words:")
print(words)

print("Lemmatized Words:")

for word in words:
    print(word, "->", lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\CCF\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Original Words:
# ['playing', 'played', 'studies', 'cars', 'running']
# Lemmatized Words:
# playing -> playing
# played -> played
# studies -> study
# cars -> car
# running -> running

# %%
#Text Normalization

import re

text = "   I LOOOOOVE THIS MOVIE!!!   "

print("Before:")
print(text)

text = text.lower()

text = re.sub(r"(.)\1{2,}", r"\1\1", text)

text = re.sub(r"[^\w\s]", "", text)

text = re.sub(r"\s+", " ", text).strip()

print("After Normalization:")
print(text)
# Out:
# Before:
#    I LOOOOOVE THIS MOVIE!!!
# After Normalization:
# i loove this movie

# %%
# True Casing

text = "i love natural language processing. it is very interesting."

sentences = text.split(". ")

result = []

for sentence in sentences:
    sentence = sentence.strip()

    if sentence:
        sentence = sentence[0].upper() + sentence[1:]
        result.append(sentence)

print("Before:")
print(text)

print("\nAfter True Casing:")

for sentence in result:
    print(sentence)
# Out:
# Before:
# i love natural language processing. it is very interesting.
#
# After True Casing:
# I love natural language processing
# It is very interesting.

# %%
# OOV Word Identification

text = "I love this amazing movie"

vocabulary = {
    "i",
    "love",
    "this",
    "movie"
}

words = text.lower().split()

oov_words = []

for word in words:
    if word not in vocabulary:
        oov_words.append(word)

print("Words:")
print(words)

print("OOV Words:")
print(oov_words)
# Out:
# Words:
# ['i', 'love', 'this', 'amazing', 'movie']
# OOV Words:
# ['amazing']

# %%
# OOV Handling Using

text = "I love this amazing movie"

vocabulary = {
    "i",
    "love",
    "this",
    "movie"
}

words = text.lower().split()

result = []

for word in words:
    if word in vocabulary:
        result.append(word)
    else:
        result.append("<UNK>")

print("Original:")
print(text)

print("After OOV Handling:")
print(result)
# Out:
# Original:
# I love this amazing movie
# After OOV Handling:
# ['i', 'love', 'this', '<UNK>', 'movie']
